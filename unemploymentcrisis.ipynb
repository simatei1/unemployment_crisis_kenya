# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('unemployment analysis.csv')
df.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %%
df.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.278000    7.626340    8.070766    8.246043    8.333915    8.494894
# std      6.013749    6.296617    6.335855    6.243778    6.330822    6.358431
# min      0.300000    0.340000    0.410000    0.470000    0.500000    0.560000
# 25%      2.945000    3.140000    3.700000    3.890000    3.945000    3.995000
# 50%      5.410000    5.710000    6.030000    6.550000    6.700000    7.050000
# 75%      9.815000   10.170000   10.895000   11.110000   11.050000   11.405000
# max     36.120000   36.390000   36.740000   36.980000   37.340000   38.800000
#
#              1997        1998        1999        2000  ...        2012  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.394043    8.441064    8.568043    8.438979  ...    8.062553
# ...

# %%
Kenya=df.loc[df['Country Name']=="Kenya"]
Kenya=Kenya.drop(columns=['Country Name', 'Country Code'])
Uganda=df.loc[df['Country Name']=="Uganda"]
Tanzania=df.loc[df['Country Name']=="Tanzania"]
China=df.loc[df['Country Name']=="China"]
USA=df.loc[df['Country Name']=="United States"]
Tanzania
Kenya=Kenya.transpose()
Kenya=Kenya.reset_index()
Kenya.to_csv('ke.csv')
Kenya=pd.read_csv('kenew.csv')
Kenya
# Out:
#     Year  Unemployment
# 0   1991          3.12
# 1   1992          3.12
# 2   1993          3.10
# 3   1994          3.08
# 4   1995          3.06
# 5   1996          3.05
# 6   1997          3.06
# 7   1998          3.03
# 8   1999          3.02
# 9   2000          3.02
# 10  2001          2.99
# 11  2002          3.00
# 12  2003          2.97
# 13  2004          2.94
# 14  2005          2.92
# 15  2006          2.91
# 16  2007          2.89
# 17  2008          2.92
# 18  2009          2.88
# 19  2010          2.84
# 20  2011          2.84
# 21  2012          2.83
# 22  2013          2.81
# 23  2014          2.80
# 24  2015          2.78
# 25  2016          2.76
# 26  2017          3.51
# 27  2018          4.25
# 28  2019          5.01
# 29  2020          5.73
# 30  2021          5.74

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)#no missing values
# Out:
# Country Name    0
# Country Code    0
# 1991            0
# 1992            0
# 1993            0
# 1994            0
# 1995            0
# 1996            0
# 1997            0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
#Let's plot some line graphs to show unemployment rate over time
plt.plot(Kenya.Year, Kenya.Unemployment)
plt.xlabel("Year")
plt.ylabel("Unemployment Index in %")
plt.title("Kenya Unemployment Index")
plt.show()
